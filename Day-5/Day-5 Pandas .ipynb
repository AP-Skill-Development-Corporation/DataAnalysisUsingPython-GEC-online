# %% [markdown]
# # Data Frames
#
# it is having Rows and columns

# %%
# create Data frame by using list
import pandas as pd
li = [12,3,4,6,57,87,98]
df = pd.DataFrame(li)

# %%
df
# Out:
#     0
# 0  12
# 1   3
# 2   4
# 3   6
# 4  57
# 5  87
# 6  98

# %%
df.columns = ['value']

# %%
df
# Out:
#    value
# 0     12
# 1      3
# 2      4
# 3      6
# 4     57
# 5     87
# 6     98

# %%
li1 = [[1,24,5],[56,87,23],[2,4,7]]
df1 = pd.DataFrame(li1)

# %%
df1
# Out:
#     0   1   2
# 0   1  24   5
# 1  56  87  23
# 2   2   4   7

# %%
df1.index = ['a','b','c']
df1
# Out:
#     0   1   2
# a   1  24   5
# b  56  87  23
# c   2   4   7

# %%
df1.columns = ['col1','col2','col3']
df1
# Out:
#    col1  col2  col3
# a     1    24     5
# b    56    87    23
# c     2     4     7

# %%
df3 = pd.DataFrame(pd.Series([12,343,45], index= [100,101,102]))
df3
# Out:
#        0
# 100   12
# 101  343
# 102   45

# %%
# creating a data Frame using Dict
di = {'names':['kiran', 'satya','joy', 'ankith'],
    'age': [21,20,19,21],
      'branch':['ece', 'cse', 'ece','eee']
}
df5 = pd.DataFrame(di)
df5
# Out:
#     names  age branch
# 0   kiran   21    ece
# 1   satya   20    cse
# 2     joy   19    ece
# 3  ankith   21    eee

# %%
di = {'names':pd.Series(['kiran', 'satya','joy', 'ankith'], index= [1,2,3,4]),
    'age': pd.Series([21,20,19],index= [1,3,4]),
      'branch':pd.Series(['ece', 'cse'], index=[2,3])
}
di
# Out:
# {'names': 1     kiran
#  2     satya
#  3       joy
#  4    ankith
#  dtype: object,
#  'age': 1    21
#  3    20
#  4    19
#  dtype: int64,
#  'branch': 2    ece
#  3    cse
#  dtype: object}

# %%
df5 = pd.DataFrame(di)

# %%
df5
# Out:
#     names   age branch
# 1   kiran  21.0    NaN
# 2   satya   NaN    ece
# 3     joy  20.0    cse
# 4  ankith  19.0    NaN

# %%
data = [{'squares': num**2, 'cubes': num**3} for num in range(100,121)]

# %%
data
# Out:
# [{'squares': 10000, 'cubes': 1000000},
#  {'squares': 10201, 'cubes': 1030301},
#  {'squares': 10404, 'cubes': 1061208},
#  {'squares': 10609, 'cubes': 1092727},
#  {'squares': 10816, 'cubes': 1124864},
#  {'squares': 11025, 'cubes': 1157625},
#  {'squares': 11236, 'cubes': 1191016},
#  {'squares': 11449, 'cubes': 1225043},
#  {'squares': 11664, 'cubes': 1259712},
#  {'squares': 11881, 'cubes': 1295029},
#  {'squares': 12100, 'cubes': 1331000},
#  {'squares': 12321, 'cubes': 1367631},
#  {'squares': 12544, 'cubes': 1404928},
#  {'squares': 12769, 'cubes': 1442897},
#  {'squares': 12996, 'cubes': 1481544},
#  {'squares': 13225, 'cubes': 1520875},
#  {'squares': 13456, 'cubes': 1560896},
#  {'squares': 13689, 'cubes': 1601613},
#  {'squares': 13924, 'cubes': 1643032},
#  {'squares': 14161, 'cubes': 1685159},
#  {'squares': 14400, 'cubes': 1728000}]

# %%
import numpy as np
df6 = pd.DataFrame(data, index = np.arange(100,121), columns =['squares', 'cubes'])
df6
# Out:
#      squares    cubes
# 100    10000  1000000
# 101    10201  1030301
# 102    10404  1061208
# 103    10609  1092727
# 104    10816  1124864
# 105    11025  1157625
# 106    11236  1191016
# 107    11449  1225043
# 108    11664  1259712
# 109    11881  1295029
# 110    12100  1331000
# 111    12321  1367631
# 112    12544  1404928
# 113    12769  1442897
# 114    12996  1481544
# 115    13225  1520875
# 116    13456  1560896
# 117    13689  1601613
# 118    13924  1643032
# 119    14161  1685159
# 120    14400  1728000

# %%
data
# Out:
# [{'squares': 10000, 'cubes': 1000000},
#  {'squares': 10201, 'cubes': 1030301},
#  {'squares': 10404, 'cubes': 1061208},
#  {'squares': 10609, 'cubes': 1092727},
#  {'squares': 10816, 'cubes': 1124864},
#  {'squares': 11025, 'cubes': 1157625},
#  {'squares': 11236, 'cubes': 1191016},
#  {'squares': 11449, 'cubes': 1225043},
#  {'squares': 11664, 'cubes': 1259712},
#  {'squares': 11881, 'cubes': 1295029},
#  {'squares': 12100, 'cubes': 1331000},
#  {'squares': 12321, 'cubes': 1367631},
#  {'squares': 12544, 'cubes': 1404928},
#  {'squares': 12769, 'cubes': 1442897},
#  {'squares': 12996, 'cubes': 1481544},
#  {'squares': 13225, 'cubes': 1520875},
#  {'squares': 13456, 'cubes': 1560896},
#  {'squares': 13689, 'cubes': 1601613},
#  {'squares': 13924, 'cubes': 1643032},
#  {'squares': 14161, 'cubes': 1685159},
#  {'squares': 14400, 'cubes': 1728000}]

# %%
df6.T
# Out:
#              100      101      102      103      104      105      106  \
# squares    10000    10201    10404    10609    10816    11025    11236
# cubes    1000000  1030301  1061208  1092727  1124864  1157625  1191016
#
#              107      108      109  ...      111      112      113      114  \
# squares    11449    11664    11881  ...    12321    12544    12769    12996
# cubes    1225043  1259712  1295029  ...  1367631  1404928  1442897  1481544
#
#              115      116      117      118      119      120
# squares    13225    13456    13689    13924    14161    14400
# cubes    1520875  1560896  1601613  1643032  1685159  1728000
#
# [2 rows x 21 columns]

# %% [markdown]
# ### Combining the data

# %%
df6
# Out:
#      squares    cubes
# 100    10000  1000000
# 101    10201  1030301
# 102    10404  1061208
# 103    10609  1092727
# 104    10816  1124864
# 105    11025  1157625
# 106    11236  1191016
# 107    11449  1225043
# 108    11664  1259712
# 109    11881  1295029
# 110    12100  1331000
# 111    12321  1367631
# 112    12544  1404928
# 113    12769  1442897
# 114    12996  1481544
# 115    13225  1520875
# 116    13456  1560896
# 117    13689  1601613
# 118    13924  1643032
# 119    14161  1685159
# 120    14400  1728000

# %%
pd.concat([df6,df],axis= 1)# axis = (0 --rows) (1- columns)
# Out:
#      squares      cubes  value
# 0        NaN        NaN   12.0
# 1        NaN        NaN    3.0
# 2        NaN        NaN    4.0
# 3        NaN        NaN    6.0
# 4        NaN        NaN   57.0
# 5        NaN        NaN   87.0
# 6        NaN        NaN   98.0
# 100  10000.0  1000000.0    NaN
# 101  10201.0  1030301.0    NaN
# 102  10404.0  1061208.0    NaN
# 103  10609.0  1092727.0    NaN
# 104  10816.0  1124864.0    NaN
# 105  11025.0  1157625.0    NaN
# 106  11236.0  1191016.0    NaN
# 107  11449.0  1225043.0    NaN
# 108  11664.0  1259712.0    NaN
# 109  11881.0  1295029.0    NaN
# 110  12100.0  1331000.0    NaN
# 111  12321.0  1367631.0    NaN
# 112  12544.0  1404928.0    NaN
# 113  12769.0  1442897.0    NaN
# 114  12996.0  1481544.0    NaN
# 115  13225.0  1520875.0    NaN
# 116  13456.0  1560896.0    NaN
# 117  13689.0  1601613.0    NaN
# 118  13924.0  1643032.0    NaN
# 119  14161.0  1685159.0    NaN
# 120  14400.0  1728000.0    NaN

# %%
pd.concat([df6,df],axis= 0)
# Out:
#      squares      cubes  value
# 100  10000.0  1000000.0    NaN
# 101  10201.0  1030301.0    NaN
# 102  10404.0  1061208.0    NaN
# 103  10609.0  1092727.0    NaN
# 104  10816.0  1124864.0    NaN
# 105  11025.0  1157625.0    NaN
# 106  11236.0  1191016.0    NaN
# 107  11449.0  1225043.0    NaN
# 108  11664.0  1259712.0    NaN
# 109  11881.0  1295029.0    NaN
# 110  12100.0  1331000.0    NaN
# 111  12321.0  1367631.0    NaN
# 112  12544.0  1404928.0    NaN
# 113  12769.0  1442897.0    NaN
# 114  12996.0  1481544.0    NaN
# 115  13225.0  1520875.0    NaN
# 116  13456.0  1560896.0    NaN
# 117  13689.0  1601613.0    NaN
# 118  13924.0  1643032.0    NaN
# 119  14161.0  1685159.0    NaN
# 120  14400.0  1728000.0    NaN
# 0        NaN        NaN   12.0
# 1        NaN        NaN    3.0
# 2        NaN        NaN    4.0
# 3        NaN        NaN    6.0
# 4        NaN        NaN   57.0
# 5        NaN        NaN   87.0
# 6        NaN        NaN   98.0

# %%
pd.concat([df6,df6],axis= 1)
# Out:
#      squares    cubes  squares    cubes
# 100    10000  1000000    10000  1000000
# 101    10201  1030301    10201  1030301
# 102    10404  1061208    10404  1061208
# 103    10609  1092727    10609  1092727
# 104    10816  1124864    10816  1124864
# 105    11025  1157625    11025  1157625
# 106    11236  1191016    11236  1191016
# 107    11449  1225043    11449  1225043
# 108    11664  1259712    11664  1259712
# 109    11881  1295029    11881  1295029
# 110    12100  1331000    12100  1331000
# 111    12321  1367631    12321  1367631
# 112    12544  1404928    12544  1404928
# 113    12769  1442897    12769  1442897
# 114    12996  1481544    12996  1481544
# 115    13225  1520875    13225  1520875
# 116    13456  1560896    13456  1560896
# 117    13689  1601613    13689  1601613
# 118    13924  1643032    13924  1643032
# 119    14161  1685159    14161  1685159
# 120    14400  1728000    14400  1728000

# %%
pd.concat([df6,df6],axis= 0)
# Out:
#      squares    cubes
# 100    10000  1000000
# 101    10201  1030301
# 102    10404  1061208
# 103    10609  1092727
# 104    10816  1124864
# 105    11025  1157625
# 106    11236  1191016
# 107    11449  1225043
# 108    11664  1259712
# 109    11881  1295029
# 110    12100  1331000
# 111    12321  1367631
# 112    12544  1404928
# 113    12769  1442897
# 114    12996  1481544
# 115    13225  1520875
# 116    13456  1560896
# 117    13689  1601613
# 118    13924  1643032
# 119    14161  1685159
# 120    14400  1728000
# 100    10000  1000000
# 101    10201  1030301
# 102    10404  1061208
# 103    10609  1092727
# 104    10816  1124864
# 105    11025  1157625
# 106    11236  1191016
# 107    11449  1225043
# 108    11664  1259712
# 109    11881  1295029
# 110    12100  1331000
# 111    12321  1367631
# 112    12544  1404928
# 113    12769  1442897
# 114    12996  1481544
# 115    13225  1520875
# 116    13456  1560896
# 117    13689  1601613
# 118    13924  1643032
# ...

# %%
df5
# Out:
#     names   age branch
# 1   kiran  21.0    NaN
# 2   satya   NaN    ece
# 3     joy  20.0    cse
# 4  ankith  19.0    NaN

# %%
df7 = pd.DataFrame({'names': pd.Series(['kiran', 'satya', 'joy', 'ankith'], index=[1,2,3,4]),
                   'marks':pd.Series([27,43,34,67], index= [1,2,3,4])})
df7
# Out:
#     names  marks
# 1   kiran     27
# 2   satya     43
# 3     joy     34
# 4  ankith     67

# %%
pd.merge(df5,df7)
# Out:
#     names   age branch  marks
# 0   kiran  21.0    NaN     27
# 1   satya   NaN    ece     43
# 2     joy  20.0    cse     34
# 3  ankith  19.0    NaN     67

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left, right, how: str = 'inner', on=None, left_on=None, right_on=None, left_index: bool = False, right_index: bool = False, sort: bool = False, suffixes=('_x', '_y'), copy: bool = True, indicator: bool = False, validate=None) -> 'DataFrame'
#     Merge DataFrame or named Series objects with a database-style join.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
#
#     Parameters
#     ----------
#     left : DataFrame
#     right : DataFrame or named Series
#         Object to merge with.
#     how : {'left', 'right', 'outer', 'inner'}, default 'inner'
#         Type of merge to be performed.
#
#         * left: use only keys from left frame, similar to a SQL left outer join;
#           preserve key order.
# ...

# %%
pd.merge(df5,df7, how= 'right')
# Out:
#     names   age branch  marks
# 0   kiran  21.0    NaN     27
# 1   satya   NaN    ece     43
# 2     joy  20.0    cse     34
# 3  ankith  19.0    NaN     67

# %%
pd.merge(df5,df7, how='left')
# Out:
#     names   age branch  marks
# 0   kiran  21.0    NaN     27
# 1   satya   NaN    ece     43
# 2     joy  20.0    cse     34
# 3  ankith  19.0    NaN     67

# %%
df5
# Out:
#     names   age branch
# 1   kiran  21.0    NaN
# 2   satya   NaN    ece
# 3     joy  20.0    cse
# 4  ankith  19.0    NaN

# %%
df7
# Out:
#     names  marks
# 1   kiran     27
# 2   satya     43
# 3     joy     34
# 4  ankith     67

# %%
df5['age'][2]
# Out:
# nan

# %% [markdown]
# # Select with Loc and Iloc
#
# Loc - Labled data
# iloc - Integer / labled values

# %%
df5
# Out:
#     names   age branch
# 1   kiran  21.0    NaN
# 2   satya   NaN    ece
# 3     joy  20.0    cse
# 4  ankith  19.0    NaN

# %%
df5.loc[2, ['age']]
# Out:
# age    NaN
# Name: 2, dtype: object

# %%
df5.set_index('names')
# Out:
#          age branch
# names
# kiran   21.0    NaN
# satya    NaN    ece
# joy     20.0    cse
# ankith  19.0    NaN

# %% [markdown]
# ### File Iputs

# %%
birds = pd.read_csv("https://raw.githubusercontent.com/AP-Skill-Development-Corporation/DataAnalysisUsingPython-GEC-online/main/Day-5/birds.csv")
birds
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
pd.read_csv('file1.csv')
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
txt_data = pd.read_table('sample.txt')

# %%
txt_data
# Out:
#   Roll number, name, age, Branch
# 0                 1,satya,21,ece
# 1               2,alekhya,24,cse
# 2                 3,kirthi,23,it

# %%
txt_data = pd.read_table('sample.txt',sep= ',')
txt_data
# Out:
#    Roll number     name   age  Branch
# 0            1    satya    21     ece
# 1            2  alekhya    24     cse
# 2            3   kirthi    23      it

# %%
txt_data.set_index('Roll number')
# Out:
#                 name   age  Branch
# Roll number
# 1              satya    21     ece
# 2            alekhya    24     cse
# 3             kirthi    23      it

# %%
xl_data = pd.read_excel('B4.xlsx')
Xl_data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-65-b16d8b5b50f4> in <module>
# ----> 1 xl_data = pd.read_excel('B4.xlsx')
#       2 Xl_data
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
#     303     if not isinstance(io, ExcelFile):
# ...

# %%
pip install xlrd
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'c:\program' is not recognized as an internal or external command,
# operable program or batch file.

# %%
birds
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
bird = pd.read_csv('bird.csv')

# %%
bird
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
bird.sample(10)
# Out:
#       id    huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  tarw  \
# 254  254   29.26  2.66   27.63   2.23  27.87  2.03   38.90  1.81  25.22  1.62
# 82    82  143.00  6.94  143.86   5.47  47.68  4.44  108.10  5.31  63.04  3.82
# 385  385   24.28  2.16   30.29   1.91  20.32  1.62   29.29  1.47  24.48  1.39
# 396  396   16.51  1.47   20.56   1.43  15.88  1.27     NaN  1.19  17.63  1.02
# 65    65   86.23  4.53   83.31   3.70  38.90  3.16   83.26  3.64  46.04  2.76
# 280  280   34.07  3.26   41.34   2.62  24.25  2.30   36.35  2.13  24.69  2.12
# 81    81   69.12  4.35   65.47   3.65  36.40  2.81   67.50  2.63  33.16  2.23
# 98    98   68.06  3.76   69.61   3.20  25.01  2.05   51.08  2.58  27.19  2.00
# 253  253   35.63  2.40   42.67   2.02  28.51  2.41   42.64  2.46  21.05  3.12
# 156  156  127.40  6.93  142.00   6.25  58.44  4.68  107.48  5.20  65.68  3.87
#
#     type
# 254    P
# 82    SW
# 385   SO
# 396   SO
# 65    SW
# 280    P
# 81    SW
# 98    SW
# 253    R
# ...

# %%
bird.head(10)
# Out:
#    id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  tarw  \
# 0   0   80.78   6.68   72.01   4.88  41.81  3.70    5.50  4.03  38.70  3.84
# 1   1   88.91   6.63   80.53   5.59  47.04  4.30   80.22  4.51  41.50  4.01
# 2   2   79.97   6.37   69.26   5.28  43.07  3.90   75.35  4.04  38.31  3.34
# 3   3   77.65   5.70   65.76   4.77  40.04  3.52   69.17  3.40  35.78  3.41
# 4   4   62.80   4.84   52.09   3.73  33.95  2.72   56.27  2.96  31.88  3.13
# 5   5   61.92   4.78   50.46   3.47  49.52  4.41   56.95  2.73  29.07  2.83
# 6   6   79.73   5.94   67.39   4.50  42.07  3.41   71.26  3.56  37.22  3.64
# 7   7   86.98   5.68   74.52   4.55  44.46  3.78   76.02  3.81  37.94  3.81
# 8   8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62  4.37
# 9   9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67  6.34
#
#   type
# 0   SW
# 1   SW
# 2   SW
# 3   SW
# 4   SW
# 5   SW
# 6   SW
# 7   SW
# 8   SW
# 9   SW

# %%
bird.shape
# Out:
# (420, 12)

# %%
bird['type'].unique()
# Out:
# array(['SW', 'W', 'T', 'R', 'P', 'SO'], dtype=object)

# %%
g_birds = bird.groupby('type')

# %%
g_birds # Group_names , records

# %%
for g_names, records in g_birds:
    print(g_names, records)
# Out:
# P       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 254  254  29.26  2.66  27.63   2.23  27.87  2.03  38.90  1.81  25.22  1.62
# 255  255  30.60  2.45  25.90   1.87  32.36  2.10  50.25  1.88  33.58  1.88
# 256  256  30.25  2.29  25.14   1.87  31.61  2.18  50.98  2.00  33.50  1.93
# 257  257  42.52  2.99  36.73   2.91  52.24  3.81  81.57  3.71  61.27  2.71
# 258  258  45.60  3.35  38.73   3.52  54.45  4.10  83.59  3.72  63.91  2.67
# 259  259  43.97  3.54  38.38   3.14  52.49  4.25  83.15  4.12  61.08  3.04
# 260  260  46.38  3.41  39.80   3.48  54.67  4.08  85.88  4.04  63.75  3.09
# 261  261  45.57  4.64  57.13   2.93  28.32  2.26  36.95  1.96  19.75  2.16
# 262  262  33.81  2.80  42.82   2.22  18.88  1.45  26.28  1.31  14.45  1.29
# 263  263  31.72  2.64  40.00   1.99  20.36  1.59  32.21  1.62  17.72  1.52
# 264  264   9.85  2.88  14.73   1.73  16.27  1.22  20.89  1.25   7.77  1.23
# ...

# %%
g_birds.get_group('SO').sample(10)
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 398  398  15.55  1.48  18.93   1.30  17.58  1.23  31.65  1.14  24.12  0.98
# 314  314  20.36  1.91  21.92   1.54  21.56  1.81  36.81  1.56  26.31  1.27
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 379  379  22.26  1.94  27.69   1.71  17.27  1.28  27.29  1.26  17.49  1.02
# 326  326  26.49  2.38  30.38   2.04  22.99  2.14  42.19  1.87  33.71  1.46
# 409  409  23.27  2.15  27.62   2.16  21.86  1.64  35.55  1.51  23.23  1.32
# 405  405  17.30  1.68  20.43   1.33  15.51  1.15  25.96  0.88  17.41  0.81
# 356  356  18.30  1.69  22.97   1.48  18.16  1.50  36.39  1.24  27.46  0.98
# 311  311  22.26  1.77  24.58   1.67  21.28  1.68  36.06  1.43  24.14  1.41
# 399  399  23.32  2.06  27.90   1.84  22.49  1.66  34.77  1.42  23.05  1.18
#
#     type
# 398   SO
# 314   SO
# 415   SO
# 379   SO
# 326   SO
# 409   SO
# 405   SO
# 356   SO
# 311   SO
# 399   SO

# %%
g_birds.first() # it returns first record of each group
# Out:
#        id    huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw    tarl  \
# type
# P     254   29.26  2.66   27.63   2.23  27.87  2.03   38.90  1.81   25.22
# R     204   63.76  4.74   69.06   4.08  57.33  4.88   75.67  4.33   60.19
# SO    292   29.61  2.41   33.93   2.02  30.79  2.19   51.64  2.01   37.33
# SW      0   80.78  6.68   72.01   4.88  41.81  3.70    5.50  4.03   38.70
# T     181   43.97  4.64   51.07   3.80  38.76  3.18   55.67  2.88   30.41
# W     116  157.00  9.00  192.00   7.02  85.60  6.44  227.00  6.84  175.00
#
#       tarw
# type
# P     1.62
# R     3.82
# SO    1.78
# SW    3.84
# T     2.83
# W     6.77

# %%
g_birds.last()
# Out:
#        id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# P     291  41.60  3.74  56.50   3.02  37.00  2.99  62.90  2.82  38.21  2.51
# R     253  35.63  2.40  42.67   2.02  28.51  2.41  42.64  2.46  21.05  3.12
# SO    419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
# SW    115  98.73  6.48  91.69   5.31  35.34  4.02  92.36  4.46  50.53  2.69
# T     203  39.64  4.07  37.32   2.98  45.50  3.42  64.45  3.37  37.77  2.86
# W     180  87.01  5.18  94.34   4.45  35.73  2.80  67.12  2.93  43.43  2.34

# %%
group2 = bird.groupby(['type','id'])
group2.first()
# Out:
#            huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type id
# P    254  29.26  2.66  27.63   2.23  27.87  2.03  38.90  1.81  25.22  1.62
#      255  30.60  2.45  25.90   1.87  32.36  2.10  50.25  1.88  33.58  1.88
#      256  30.25  2.29  25.14   1.87  31.61  2.18  50.98  2.00  33.50  1.93
#      257  42.52  2.99  36.73   2.91  52.24  3.81  81.57  3.71  61.27  2.71
#      258  45.60  3.35  38.73   3.52  54.45  4.10  83.59  3.72  63.91  2.67
# ...         ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# W    176  33.20  2.11  34.31   2.25  20.36  1.57  37.95  1.42  23.67  1.26
#      177  32.31  2.16  32.74   1.98  19.05  1.40  33.37  1.14  21.20  1.00
#      178  28.51  1.80  29.35   1.78  17.60  1.21  36.04  1.14  20.81  0.83
#      179  34.12  1.90  35.57   1.93  21.22  1.39  46.24  1.27  31.39  1.05
#      180  87.01  5.18  94.34   4.45  35.73  2.80  67.12  2.93  43.43  2.34
#
# [420 rows x 10 columns]

# %%
bird
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
bird.mean()
# Out:
# id       209.500000
# huml      64.650501
# humw       4.370573
# ulnal     69.115372
# ulnaw      3.597249
# feml      36.872416
# femw       3.220883
# tibl      64.662823
# tibw       3.182339
# tarl      39.229976
# tarw       2.930024
# dtype: float64

# %%
bird.isnull().sum()
# Out:
# id       0
# huml     1
# humw     1
# ulnal    3
# ulnaw    2
# feml     2
# femw     1
# tibl     2
# tibw     1
# tarl     1
# tarw     1
# type     0
# dtype: int64

# %%
bird.count()
# Out:
# id       420
# huml     419
# humw     419
# ulnal    417
# ulnaw    418
# feml     418
# femw     419
# tibl     418
# tibw     419
# tarl     419
# tarw     419
# type     420
# dtype: int64

# %%
bird['tibl'].min()
# Out:
# 5.5

# %%
bird['tibl'].max()
# Out:
# 240.0

# %%
bird['huml']>90
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 415    False
# 416    False
# 417    False
# 418    False
# 419    False
# Name: huml, Length: 420, dtype: bool

# %%
bird[bird['huml']>90]
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 8      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# 10    10  165.00  11.45  156.00   8.68  80.25  7.85  143.00  8.25  86.61
# 11    11  186.00   9.83  152.00   8.76  56.02  7.02  185.00  8.07  90.80
# 12    12  172.00   8.44  142.00   8.43  52.18  6.68  180.00  9.62  82.58
# ..   ...     ...    ...     ...    ...    ...   ...     ...   ...    ...
# 246  246   90.13   5.92  104.28   4.40  54.55  4.65   94.99  4.42  67.55
# 247  247  100.29   6.33  112.19   4.69  59.71  4.94  102.54  5.33  71.03
# 248  248   96.46   5.71  111.85   4.20  59.82  4.65   99.16  4.56  73.95
# 249  249   93.37   5.33  102.65   3.90  58.55  4.62  101.24  4.57  71.30
# 250  250   99.69   6.09  111.00   4.26  60.84  4.75  104.72  4.92  71.23
#
#      tarw type
# 8    4.37   SW
# 9    6.34   SW
# 10   6.63   SW
# 11   4.59   SW
# ...

# %%
bird[(bird['huml']>90) & (bird['huml']<150)]
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 8      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# 13    13  148.91   6.78  121.35   6.50  44.29  6.33  155.00  6.68  73.71
# 14    14  149.19   6.98  121.48   6.21  43.33  5.39  155.00  6.61  75.65
# 15    15  140.59   6.59  115.97   5.81  39.75  5.61  166.00  7.83  74.86
# ..   ...     ...    ...     ...    ...    ...   ...     ...   ...    ...
# 246  246   90.13   5.92  104.28   4.40  54.55  4.65   94.99  4.42  67.55
# 247  247  100.29   6.33  112.19   4.69  59.71  4.94  102.54  5.33  71.03
# 248  248   96.46   5.71  111.85   4.20  59.82  4.65   99.16  4.56  73.95
# 249  249   93.37   5.33  102.65   3.90  58.55  4.62  101.24  4.57  71.30
# 250  250   99.69   6.09  111.00   4.26  60.84  4.75  104.72  4.92  71.23
#
#      tarw type
# 8    4.37   SW
# 9    6.34   SW
# 13   4.24   SW
# 14   3.36   SW
# ...

# %%
bird['type'] == 'P'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 415    False
# 416    False
# 417    False
# 418    False
# 419    False
# Name: type, Length: 420, dtype: bool

# %%
bird[bird['type'] == 'P']
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 254  254  29.26  2.66  27.63   2.23  27.87  2.03  38.90  1.81  25.22  1.62
# 255  255  30.60  2.45  25.90   1.87  32.36  2.10  50.25  1.88  33.58  1.88
# 256  256  30.25  2.29  25.14   1.87  31.61  2.18  50.98  2.00  33.50  1.93
# 257  257  42.52  2.99  36.73   2.91  52.24  3.81  81.57  3.71  61.27  2.71
# 258  258  45.60  3.35  38.73   3.52  54.45  4.10  83.59  3.72  63.91  2.67
# 259  259  43.97  3.54  38.38   3.14  52.49  4.25  83.15  4.12  61.08  3.04
# 260  260  46.38  3.41  39.80   3.48  54.67  4.08  85.88  4.04  63.75  3.09
# 261  261  45.57  4.64  57.13   2.93  28.32  2.26  36.95  1.96  19.75  2.16
# 262  262  33.81  2.80  42.82   2.22  18.88  1.45  26.28  1.31  14.45  1.29
# 263  263  31.72  2.64  40.00   1.99  20.36  1.59  32.21  1.62  17.72  1.52
# 264  264   9.85  2.88  14.73   1.73  16.27  1.22  20.89  1.25   7.77  1.23
# ...

# %%
bird.sort_index(axis= 1, ascending=True)
# Out:
#       feml  femw   huml  humw   id   tarl  tarw   tibl  tibw type  ulnal  \
# 0    41.81  3.70  80.78  6.68    0  38.70  3.84   5.50  4.03   SW  72.01
# 1    47.04  4.30  88.91  6.63    1  41.50  4.01  80.22  4.51   SW  80.53
# 2    43.07  3.90  79.97  6.37    2  38.31  3.34  75.35  4.04   SW  69.26
# 3    40.04  3.52  77.65  5.70    3  35.78  3.41  69.17  3.40   SW  65.76
# 4    33.95  2.72  62.80  4.84    4  31.88  3.13  56.27  2.96   SW  52.09
# ..     ...   ...    ...   ...  ...    ...   ...    ...   ...  ...    ...
# 415  18.36  1.54  17.96  1.63  415  21.99  1.15  31.25  1.33   SO  19.25
# 416  19.24  1.45  19.21  1.64  416  23.60  1.15  33.21  1.28   SO  20.76
# 417  20.96  1.43  18.79  1.63  417  22.86  1.21  34.45  1.41   SO  19.83
# 418  21.35  1.48  20.38  1.78  418  25.98  1.24  36.09  1.53   SO  22.53
# 419  17.62  1.34  17.89  1.44  419  21.69  1.05  29.81  1.24   SO  19.26
#
#      ulnaw
# 0     4.88
# 1     5.59
# 2     5.28
# 3     4.77
# 4     3.73
# ..     ...
# ...

# %%
bird.sort_index(axis= 1, ascending=False)
# Out:
#      ulnaw  ulnal type  tibw   tibl  tarw   tarl   id  humw   huml  femw  \
# 0     4.88  72.01   SW  4.03   5.50  3.84  38.70    0  6.68  80.78  3.70
# 1     5.59  80.53   SW  4.51  80.22  4.01  41.50    1  6.63  88.91  4.30
# 2     5.28  69.26   SW  4.04  75.35  3.34  38.31    2  6.37  79.97  3.90
# 3     4.77  65.76   SW  3.40  69.17  3.41  35.78    3  5.70  77.65  3.52
# 4     3.73  52.09   SW  2.96  56.27  3.13  31.88    4  4.84  62.80  2.72
# ..     ...    ...  ...   ...    ...   ...    ...  ...   ...    ...   ...
# 415   1.33  19.25   SO  1.33  31.25  1.15  21.99  415  1.63  17.96  1.54
# 416   1.49  20.76   SO  1.28  33.21  1.15  23.60  416  1.64  19.21  1.45
# 417   1.53  19.83   SO  1.41  34.45  1.21  22.86  417  1.63  18.79  1.43
# 418   1.50  22.53   SO  1.53  36.09  1.24  25.98  418  1.78  20.38  1.48
# 419   1.10  19.26   SO  1.24  29.81  1.05  21.69  419  1.44  17.89  1.34
#
#       feml
# 0    41.81
# 1    47.04
# 2    43.07
# 3    40.04
# 4    33.95
# ..     ...
# ...

# %%
bird.sort_values(by='type',ascending= True)
# Out:
#       id    huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  tarw  \
# 270  270   26.92  2.73   31.54   2.01  19.10  1.59   26.68  1.35  13.21  1.23
# 269  269   27.07  2.66   31.95   1.87  18.80  1.51   26.38  1.33  12.52  1.16
# 268  268   27.57  2.67   31.60   2.12  18.92  1.52   30.42  1.58  12.46  1.46
# 267  267   18.55  2.12   21.08   1.41  18.19  1.30   25.97  1.17  11.26  1.57
# 266  266   18.46  1.79   21.12   1.47  18.83  1.21   26.33  1.05  11.41  1.56
# ..   ...     ...   ...     ...    ...    ...   ...     ...   ...    ...   ...
# 167  167   80.00  4.70  111.96   4.87  40.17  3.34   68.89  3.25  33.69  2.70
# 168  168   50.96  3.32   59.14   3.18  22.68  1.74   37.49  2.06  15.91  1.71
# 169  169   25.10  1.68   26.11   1.73  17.86  1.33   35.85  1.20  23.44  1.05
# 171  171   22.89  1.55   24.62   1.59  15.71  1.14   34.27  1.06  21.02  1.04
# 153  153  138.09  8.08  155.49   7.43  63.14  5.45  125.00  4.66  75.17  4.11
#
#     type
# 270    P
# 269    P
# ...

# %%
bird.describe()
# Out:
#                id        huml        humw       ulnal       ulnaw        feml  \
# count  420.000000  419.000000  419.000000  417.000000  418.000000  418.000000
# mean   209.500000   64.650501    4.370573   69.115372    3.597249   36.872416
# std    121.387808   53.834549    2.854617   58.784775    2.186747   19.979082
# min      0.000000    9.850000    1.140000   14.090000    1.000000   11.830000
# 25%    104.750000   25.170000    2.190000   28.050000    1.870000   21.297500
# 50%    209.500000   44.180000    3.500000   43.710000    2.945000   31.130000
# 75%    314.250000   90.310000    5.810000   97.520000    4.770000   47.120000
# max    419.000000  420.000000   17.840000  422.000000   12.000000  117.070000
#
#              femw        tibl        tibw        tarl        tarw
# count  419.000000  418.000000  419.000000  419.000000  419.000000
# mean     3.220883   64.662823    3.182339   39.229976    2.930024
# std      2.023581   37.838145    2.080827   23.184313    2.185673
# ...

# %%
bird['huml'].min()
# Out:
# 9.85

# %%
bird['huml'].argmin()
# Out:
# 264

# %%
bird['huml'].argmax()
# Out:
# 58

# %%
bird['huml'].max()
# Out:
# 420.0

# %%
bird['huml'].idxmin()
# Out:
# 264

# %% [markdown]
# cleaning of data

# %%
emp = pd.read_csv('https://raw.githubusercontent.com/AP-Skill-Development-Corporation/DataAnalysisUsingPython-GEC-online/main/Day-5/employee.csv')
emp
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
emp.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
emp.notnull().sum()
# Out:
# First Name            933
# Gender                855
# Start Date           1000
# Last Login Time      1000
# Salary               1000
# Bonus %              1000
# Senior Management     933
# Team                  957
# dtype: int64

# %%
emp.shape
# Out:
# (1000, 8)

# %%
emp.dropna()
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# ...

# %%
emp.dropna().shape
# Out:
# (764, 8)

# %%
g_birds.first()
# Out:
#        id    huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw    tarl  \
# type
# P     254   29.26  2.66   27.63   2.23  27.87  2.03   38.90  1.81   25.22
# R     204   63.76  4.74   69.06   4.08  57.33  4.88   75.67  4.33   60.19
# SO    292   29.61  2.41   33.93   2.02  30.79  2.19   51.64  2.01   37.33
# SW      0   80.78  6.68   72.01   4.88  41.81  3.70    5.50  4.03   38.70
# T     181   43.97  4.64   51.07   3.80  38.76  3.18   55.67  2.88   30.41
# W     116  157.00  9.00  192.00   7.02  85.60  6.44  227.00  6.84  175.00
#
#       tarw
# type
# P     1.62
# R     3.82
# SO    1.78
# SW    3.84
# T     2.83
# W     6.77
